# %% [markdown]
# <a href="https://colab.research.google.com/github/PravinV001/Python/blob/main/CO2_emission_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/158/208/original/CO2_Emissions.csv?1760012266
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/158/208/original/CO2_Emissions.csv?1760012266
# To: /content/CO2_Emissions.csv?1760012266
# 100% 476k/476k [00:00<00:00, 51.7MB/s]

# %%
#importing data file in drive and reding from drive

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('/content/CO2_Emissions.csv?1760012266')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
print (df.head())
print(df['Make'].unique())
print(df['Make'].nunique())
print(df['Vehicle Class'].nunique())
print(df['Engine Size(L)'].nunique())
print(df['Transmission'].nunique())
print(df['Fuel Type'].nunique())
print(df['Engine Size(L)'].nunique())
print(df['Fuel Consumption Comb (L/100 km)'].nunique())
#*****
print(df['Vehicle Class'].unique())
print(df['Engine Size(L)'].unique())
print(df['Transmission'].unique())
print(df['Fuel Type'].unique())
print(df['Engine Size(L)'].unique())
print(df['Fuel Consumption Comb (L/100 km)'].unique())

# There is no duplicate record in this table
df=df.drop_duplicates(keep='first').reset_index(drop=True)
print('Post Drop duplicate')

df.info()
print('Dup removed')
df=df.sort_values(by='CO2 Emissions(g/km)')
df.head()
df.tail()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244
# ['ACURA' 'ALFA ROMEO' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUICK'
#  'CADILLAC' 'CHEVROLET' 'CHRYSLER' 'DODGE' 'FIAT' 'FORD' 'GMC' 'HONDA'
#  'HYUNDAI' 'INFINITI' 'JAGUAR' 'JEEP' 'KIA' 'LAMBORGHINI' 'LAND ROVER'
#  'LEXUS' 'LINCOLN' 'MASERATI' 'MAZDA' 'MERCEDES-BENZ' 'MINI' 'MITSUBISHI'
#  'NISSAN' 'PORSCHE' 'RAM' 'ROLLS-ROYCE' 'SCION' 'SMART' 'SRT' 'SUBARU'
#  'TOYOTA' 'VOLKSWAGEN' 'VOLVO' 'GENESIS' 'BUGATTI']
# 42
# 16
# 51
# 27
# 5
# 51
# 181
# ['COMPACT' 'SUV - SMALL' 'MID-SIZE' 'TWO-SEATER' 'MINICOMPACT'
#  'SUBCOMPACT' 'FULL-SIZE' 'STATION WAGON - SMALL' 'SUV - STANDARD'
#  'VAN - CARGO' 'VAN - PASSENGER' 'PICKUP TRUCK - STANDARD' 'MINIVAN'
#  'SPECIAL PURPOSE VEHICLE' 'STATION WAGON - MID-SIZE'
#  'PICKUP TRUCK - SMALL']
# [2.  2.4 1.5 3.5 3.7 1.8 5.9 4.7 3.  4.  6.3 4.2 5.2 6.  6.8 4.4 3.6 1.4
#  2.5 6.2 4.3 5.3 4.8 1.2 5.7 6.4 4.6 5.4 1.6 5.  1.  5.8 3.8 3.3 5.6 3.2
#  6.5 5.5 2.1 3.4 2.7 6.6 6.7 1.3 8.4 2.3 2.8 0.9 2.9 8.  2.2]
# ['AS5' 'M6' 'AV7' 'AS6' 'AM6' 'A6' 'AM7' 'AV8' 'AS8' 'A7' 'A8' 'M7' 'A4'
#  'M5' 'AV' 'A5' 'AS7' 'A9' 'AS9' 'AV6' 'AS4' 'AM5' 'AM8' 'AM9' 'AS10'
#  'A10' 'AV10']
# ['Z' 'D' 'X' 'E' 'N']
# [2.  2.4 1.5 3.5 3.7 1.8 5.9 4.7 3.  4.  6.3 4.2 5.2 6.  6.8 4.4 3.6 1.4
#  2.5 6.2 4.3 5.3 4.8 1.2 5.7 6.4 4.6 5.4 1.6 5.  1.  5.8 3.8 3.3 5.6 3.2
#  6.5 5.5 2.1 3.4 2.7 6.6 6.7 1.3 8.4 2.3 2.8 0.9 2.9 8.  2.2]
# [ 8.5  9.6  5.9 11.1 10.6 10.  10.1 11.6  9.2  9.8 10.4  8.4 15.6 14.7
#  15.4  8.8  9.3 10.2 10.9  8.1 11.2 11.3 12.5 15.5 10.5  9.  13.2 10.7
#  14.6 17.7 14.8 17.8 13.3 13.4 11.4 12.4 12.2 12.8 12.7  9.1 10.3 14.2
#  16.5 19.   8.7  6.7  9.9  7.9  8.3 13.8 11.  13.9 16.1 11.9 14.1 12.1
#  12.3 12.6 11.5  8.2  9.5 10.8 16.6 20.1 16.4 22.1 11.8 11.7 12.   7.8
#   7.1  7.7 16.2 17.  15.1 15.9 20.9 21.5 22.6 18.  18.8 25.7 18.2 18.9
#  25.8 14.3  8.  16.8 16.9 13.  17.3  7.5  6.9 18.4 14.4 13.1 15.7  8.6
#   7.3  7.2  6.8  6.  21.9 17.2 22.5 23.  21.2 18.3 23.9  9.4 16.  21.6
#  16.7 17.5 19.7 14.9 20.  19.9  7.6  6.6  7.   8.9  5.5 12.9  4.8  6.3
#   6.2 14.5 15.  18.1 13.7 13.5 15.8  9.7  6.4 17.4 21.4 20.7  5.6 15.3
#   7.4 14.  15.2 13.6 17.1  5.7  4.7  5.4  6.1  6.5 25.9 26.1 19.1 17.6
#  17.9 18.7  5.   5.2  5.8 18.5 16.3  5.3 19.8  5.1 21.  19.3  4.5 19.2
#  18.6 19.6  4.4  4.1 20.3 22.2 19.5  4.3 19.4  4.9 21.7 20.5  4.2]
# Post Drop duplicate
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6282 entries, 0 to 6281
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              6282 non-null   object
#  1   Model                             6282 non-null   object
#  2   Vehicle Class                     6282 non-null   object
#  3   Engine Size(L)                    6282 non-null   float64
#  4   Cylinders                         6282 non-null   int64
#  5   Transmission                      6282 non-null   object
#  6   Fuel Type                         6282 non-null   object
#  7   Fuel Consumption City (L/100 km)  6282 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   6282 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  6282 non-null   float64
#  10  Fuel Consumption Comb (mpg)       6282 non-null   int64
#  11  CO2 Emissions(g/km)               6282 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 589.1+ KB
# Dup removed
#              Make               Model    Vehicle Class  Engine Size(L)  \
# 5328  LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# 349          FORD          E350 WAGON  VAN - PASSENGER             6.8
# 5329  LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 4897      BUGATTI              Chiron       TWO-SEATER             8.0
# 4199      BUGATTI              CHIRON       TWO-SEATER             8.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5328         12          AM7         Z                              26.3
# 349          10           A5         X                              23.9
# 5329         12          AM7         Z                              26.6
# 4897         16          AM7         Z                              26.8
# 4199         16          AM7         Z                              26.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5328                             15.6                              21.5
# 349                              17.8                              21.2
# 5329                             15.8                              21.7
# 4897                             16.6                              22.2
# 4199                             16.6                              22.2
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 5328                           13                  487
# 349                            13                  488
# 5329                           13                  493
# 4897                           13                  522
# 4199                           13                  522

# %%
'''########################################
Data cleaning of Marketing Spend Table. Below are steps:
   1) checking are there any Null Values
   2) Changing Date object to Date format
   3) Get Month in both number and Char
   4) Checking duplicate row, if any
   ######################################'''


ms.info()

ms['Date'] =pd.to_datetime(ms['Date'])
ms['MonthYr']=ms['Date'].dt.strftime('%b')
ms['MonthNum'] = pd.to_datetime(ms['MonthYr'], format='%b').dt.month

null_any = ms.isnull().values.any()
if null_any == False:
 print('Marketing Spend Data is verified')
 print(ms.head(5))
 ms['Offline_Spend']=ms['Offline_Spend'].astype(float)

ms=ms.drop_duplicates(keep='first').reset_index(drop=True)

ms.info()

# %%
'''########################################
Data cleaning of customer data Spend Table
   1) checking are there any Null Value, if any
   2) Checking duplicate row, if any '''

null_any = cd.isnull().values.any()

if null_any == False:
 print('Customer Data is having no null')

cd=cd.sort_values(by='Tenure_Months')
print(cd.head(5))
cd.info()

# Dropping duplicate, if any. There is no duplicate in this table
#cd=cd.drop_duplicates(keep='first').reset_index(drop=True)
#print(cd.head(5))
#cd.info()

print('Customer Data is verified')

# %%
from pandas.core import groupby
'''########################################
Data cleaning of Operation Sales data. Below are steps:
   1) checking are there any Null Values
   2) Changing Date object to Date format
   3) Get Month in both number and Char
   4) Checking duplicate row, if any
   ######################################'''

os.info()

null_any = os.isnull().values.any()

# Changing Transaction date from object to datetime
os['Transaction_Date'] = pd.to_datetime(os['Transaction_Date'],errors='coerce')
os['MonthYr'] = pd.to_datetime(os['Transaction_Date']).dt.strftime('%b')


# Removing Duplicate records. Now, this operation is performed on the already initialized os1.
os1=os.drop_duplicates(keep='first').reset_index(drop=True)
print('Post Drop duplicate')


# There are two records which are not good removing them before analysis
if null_any == True:
  os1 = os1.dropna().reset_index(drop=True)
  print('Post Drop null')


# Changing Delivery charges and Avg Price from object to float
if 'Delivery_Charges' in os1.columns:
    os1['Delivery_Charges'] = os1['Delivery_Charges'].astype(float)
else:
    print("Warning: 'Delivery_Charges' column not found in os1.")

if 'Avg_Price' in os1.columns:
    os1['Avg_Price'] = os1['Avg_Price'].astype(float)
else:
    print("Warning: 'Avg_Price' column not found in os1.")

#Extracting Month number from Transaction Date
os1['MonthNum'] = pd.to_datetime(os1['MonthYr'], format='%b').dt.month

osfin=os1
osfin.info()

os1=os.groupby(['CustomerID','MonthYr'])['Transaction_ID'].count().reset_index()


## Remove below before final submission

#os1

## Testing Data code
#ost2=os1.sort_values(('Transaction_Date'),ascending=False)
#print(ost2.head(5))

#print(os.head(5))
#os['Transaction_Date'] = os['Transaction_Date'].str.replace('/','-')
#osdup=os[os.duplicated()]
#os.info()
#print(os[os['Transaction_ID'] == '40728'])
#print(os[os['Transaction_ID'] == '16782'])

## Belwo are two customer ID whose record I have deleted becz of data
#print(os[os['CustomerID'] == '5/2019'])
#print(os[os['CustomerID'] == '16782'])
#osdup.info()

#print(os.iloc[[20969,20970]])
#print(os.iloc[20970])
#print(os.iloc[20969])
#os = os.dropna(subset=['column'])
#osnul=os[os.isnull().any(axis=1)]
#print(osnul)
#print(os[os[Transaction_ID == 40728]])
#print(os.head(5))
#print('Operation Sales is verified')
#os['Transaction_Date'].nunique()
#print(os[['CustomerID','Transaction_ID','Transaction_Date','MonthYr']])

# %%
'''###Data cleaning of Discounted Coupans
   1) checking are there any Null Value, if any
   2) Checking duplicate row, if any
   3) Checking Data type correction, if req'''

dc.info()
null_any = dc.isnull().values.any()

if null_any == False:
 print('Discounted counpan has no null value')

# Creating additional column MonthNum from Month
dc['MonthNum'] = pd.to_datetime(dc['Month'], format='%b').dt.month


# There is no duplicate record in this table
dc=dc.drop_duplicates(keep='first').reset_index(drop=True)
print('Post Drop duplicate')

dc.info()
print('Discounted Coupan is verified')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             204 non-null    object
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.5+ KB
# Discounted counpan has no null value
# Post Drop duplicate
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             204 non-null    object
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
#  4   MonthNum          204 non-null    int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 7.3+ KB
# Discounted Coupan is verified

# %%
'''Data cleaning of tax amount
   1) checking are there any Null Value, if any
   2) Checking duplicate row, if any
   3) Checking Data type correction, if req'''

ta.info()

null_any = ta.isnull().values.any()
print(null_any)
ta.info()

ta=ta.drop_duplicates(keep='first').reset_index(drop=True)
print('Post Drop duplicate')

ta.info()
print('Tax Amount is verified')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  20 non-null     object
#  1   GST               20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes
# False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  20 non-null     object
#  1   GST               20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes
# Post Drop duplicate
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  20 non-null     object
#  1   GST               20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 452.0+ bytes
# Tax Amount is verified

# %% [markdown]
# ##########################33########
#  All Data is formated now. now we will work on Creating table which we can use to analyse data in 10 case study Q

# %%
#dc.info()
#print(dc[dc['Product_Category'] == 'Backpacks'])
#print(ta.head(2))
#print(osfin.head(2))
#print(osfin.info())

#ospc=osfin.groupby(['Product_Category','MonthNum'])['MonthYr'].count().reset_index()
#ospc=osfin.groupby(['Product_Category','MonthNum'])
#print(ospc)


osfin2=pd.merge(osfin,dc[['Discount_pct','MonthNum','Product_Category']],on=['MonthNum','Product_Category'],how='left')
#print(osfin2.head(1))
osfin2=pd.merge(osfin2,ta[['Product_Category','GST']],on=['Product_Category'],how='left')
#print(osfin2.head(1))

null_any = osfin2.isnull().values.any()
print(null_any)
osfin2.info()

# There are few product category on which there is no discount so we will get few columns with Null and
# for those changing Dic_Percentage to Zero

if null_any == False:
   print('final osfin has no Null means all join works fine')
else:
  osfin2['Discount_pct'] = osfin2['Discount_pct'].fillna(0)

  #print(osfinal.head(2))

  # If doesn't work here because of complete data frame use case
  #if osfinal.loc(['Coupon_Status'] == 'Not Used') :
  # osfinal['Rev'] = (osfinal['Quantity'] * osfinal['Avg_Price']) * (1 + osfinal['GST']) + osfinal['Delivery_Charges']
  # print(' in If'  )
  #else:
  # osfinal['Rev'] = (osfinal['Quantity'] * osfinal['Avg_Price']) * (1 - (osfinal['Discount_pct']/100)) * (1 + osfinal['GST']) + osfinal['Delivery_Charges']
  # print('in else')

  # Calculating Revenue beased on Discount Coupan used or Not
  osfinal=osfin2
  osfinal['Rev'] = np.where(
    osfinal['Coupon_Status'] == 'Not Used',
    (osfinal['Quantity'] * osfinal['Avg_Price']) * (1 + osfinal['GST']) + osfinal['Delivery_Charges'],
    (osfinal['Quantity'] * osfinal['Avg_Price']) * (1 - (osfinal['Discount_pct']/100)) * (1 + osfinal['GST']) + osfinal['Delivery_Charges']
  )
  osfinal['Rev'] = osfinal['Rev'].round(2)

  print(osfinal.head(2))

 # ((Quantity * Avg_price) * (1 - Discount_pct) * (1 + GST)) + Delivery_Charges.
# #print(dc.head(5))
#osfin2null = osfin2[osfin2['Discount_pct'].isna()]
#osfin2null = osfin2[osfin2['Discount_pct'].isna()]
#print(osfin2null)
#osfin2sum=osfin2null.groupby('Product_Category')['Transaction_ID'].count()
#print(osfin2sum)
#print(null_any)
#osfin2.info()
#osfin2.to_csv(r'/content/sample_data/CaseStudy/osfin2.csv')
# Out:
# True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  MonthYr              52924 non-null  object
#  11  MonthNum             52924 non-null  int32
#  12  Discount_pct         52524 non-null  float64
#  13  GST                  52924 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(3), object(5)
# memory usage: 5.5+ MB
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status MonthYr  MonthNum  \
# 0         1     153.71               6.5          Used     Jan         1
# 1         1     153.71               6.5          Used     Jan         1
#
#    Discount_pct  GST     Rev
# 0          10.0  0.1  158.67
# 1          10.0  0.1  158.67

# %% [markdown]
# Product category on which there is no discount are
# Product_Category
# 1) Backpacks     81
# 2) Fun          158
# 3) Google       105
# 4) More Bags     46
#
# Q1 '''First Question:
# Identify the months with the highest and lowest customer acquisition count. What strategies could be
# implemented to address the fluctuations and ensure consistent growth throughout the year?'''
#
# Q2 . Analyze the data to determine if certain months consistently show higher or lower acquisition. How can the company capitalize on high-performing months and improve performance during slower periods?

# %%
#We will be using osfinal in all question as it has data required with all relevent values from 3 tables
osq1=osfinal.sort_values(('Transaction_Date'),ascending=True)

# Dropping all duplicate to get first transaction done by customer
osq1=osq1.drop_duplicates(subset=['CustomerID'], keep='first',ignore_index=True)
#osq1.info()



########################################
'''' Analysing discount to understand aquisition count trend'''
#Getting Product wise monthly discount to understand it's impact on new customer onborading
#dc.info()
#As per data there is discount on monthly basis agnostic of product so only doing group by on month
dc1=dc.sort_values(['MonthNum','Product_Category'])
dc1=dc1.reset_index(drop=True)
dc1=dc1.groupby('MonthNum')['Discount_pct'].unique()
#print(dc1)

########################################
''' Analysing Marketing spend to understand aquisition count trend'''
#print(ms.info())
ms['Total_Spend'] = ms['Offline_Spend'] + ms['Online_Spend']
#print(ms.head(2))

#There is no trend found on online and offline spend so using total spend to understand pattern
ms2=ms.groupby('MonthNum').agg({'Total_Spend':'sum'}).reset_index()
print(ms2)

osq1=pd.merge(osq1,ms2,on=['MonthNum'],how='left')
#print(osnewc)

# Group by month to get number of transaction done by customer
osq1a=osq1.groupby('MonthNum').agg({'CustomerID':'count','Total_Spend':'unique','Discount_pct':'max','MonthYr':'unique'}).reset_index().sort_values('MonthNum')
#print(osq1a)


########################################
# To get trend when particular Product is launched so getting entry when first product is used
osq1c=osq1.drop_duplicates(subset=['Product_Category'], keep='first',ignore_index=True)

#Group by on month to understand product launch
osq1c=osq1c.groupby('MonthNum')['Product_Category'].count().reset_index().sort_values('MonthNum')
print(osq1c)

########################################
# Final DF to analyse trend for new aquititon
osq1d=pd.merge(osq1a,osq1c[['MonthNum','Product_Category']],on=['MonthNum'],how='left')

osq1d=osq1d.rename(columns=({'Product_Category':'Product_Launched'}))

osq1d['Product_Launched']= osq1d['Product_Launched'].fillna(0)
osq1d['Product_Launched']=osq1d['Product_Launched'].astype(np.int64)
#osq1d['Total_Spend']=osq1d['Total_Spend']/1000000
osq1d['Total_Spend']=osq1d['Total_Spend'].round(2)
osq1d['MonthYr']=osq1d['MonthYr'].astype(str)

print(osq1d)
osq1d.info()





#ms1=ms.groupby('MonthNum')['Offline_Spend'].sum().reset_index()
#osnewof2=pd.merge(osq1,ms1,on=['MonthNum'],how='left')
#print(osnewof2)

#ms2=ms.groupby('MonthNum')['Online_Spend'].sum().reset_index()
#print(ms2)
#osnewo1=pd.merge(osq1,ms2,on=['MonthNum'],how='left')
#print(osnewo1)


# Extract the single month string from the list in 'MonthYr'
osq1d['MonthYr_str'] = osq1d['MonthYr'].apply(lambda x: x[0] if isinstance(x, list) else x)

#### Plotting the trends

plt.figure(figsize=(20, 8))
plt.subplot(2, 2, 1)
plt.plot(osq1d['MonthYr_str'], osq1d['CustomerID'],marker='o',color='steelblue', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Customer Aquition')
plt.title('Monthly Acquisition Trend')

### Subplot 2 (Changed from original to match correct indexing and avoid duplicate plt.show() which creates separate figures)
plt.subplot(2, 2, 2)
plt.scatter(osq1d['Total_Spend'], osq1d['CustomerID'])
plt.xlabel('Total Spend in million')
plt.ylabel('Customer Acquisition')
plt.title('Monthly Total Spend vs Monthly Customer Acquisition')

### Subplot 3
plt.subplot(2, 2, 3)
plt.scatter(osq1d['Discount_pct'], osq1d['CustomerID'], color='darkorange')
plt.title('Monthly Discount vs Monthly Customer Acquisition')
plt.xlabel('Discount %')
plt.ylabel('Customer Acquisition')

### Subplot 4
plt.subplot(2, 2, 4)

plt.bar(osq1d['Product_Launched'], osq1d['CustomerID'], color='seagreen')
plt.title('Monthly Products Launched vs Monthly Customer Acquisition')
plt.xlabel('Products Launched')
plt.ylabel('Customer Acquisition')

plt.tight_layout()
plt.show()

##################
# Below is additional analysis to understand is there any part of location in getting new aquition

# merging operation sales and customer data table to get location to understand trend based on location
osca= pd.merge(osq1,cd[['CustomerID','Location']],on=['CustomerID'],how='left')
#print(osca)

# Group by month and location to get number of transaction done by customer per location
osq1b=osca.groupby(['MonthNum','Location'])['CustomerID'].count().reset_index().sort_values(['Location','MonthNum'])
osq1b=osq1b.reset_index(drop=True)
#print(osq1b)
####################
osq1b.info()
### Checking location trend for customer Aquisition

plt.figure(figsize=(15, 4))
sns.scatterplot(
    data=osq1b,
    x='MonthNum',
    y='CustomerID',
    hue='Location',
    palette='viridis'
)

plt.xlabel('Months')
plt.ylabel('Customer Acquisition')
plt.title('Location Trend for Customer Acquisition')
plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#     MonthNum  Total_Spend
# 0          1    154928.95
# 1          2    137107.92
# 2          3    122250.09
# 3          4    157026.83
# 4          5    118259.64
# 5          6    134318.14
# 6          7    120217.85
# 7          8    142904.15
# 8          9    135514.54
# 9         10    151224.65
# 10        11    161144.96
# 11        12    198648.75
#    MonthNum  Product_Category
# 0         1                12
# 1         3                 1
# 2         4                 1
# 3         5                 2
# 4         9                 2
#     MonthNum  CustomerID  Total_Spend  Discount_pct  MonthYr  Product_Launched
# 0          1         215  [154928.95]          10.0  ['Jan']                12
# 1          2          96  [137107.92]          20.0  ['Feb']                 0
# 2          3         177  [122250.09]          30.0  ['Mar']                 1
# 3          4         163  [157026.83]          10.0  ['Apr']                 1
# 4          5         112  [118259.64]          20.0  ['May']                 2
# 5          6         137  [134318.14]          30.0  ['Jun']                 0
# 6          7          94  [120217.85]          10.0  ['Jul']                 0
# 7          8         135  [142904.15]          20.0  ['Aug']                 0
# 8          9          78  [135514.54]          30.0  ['Sep']                 2
# 9         10          87  [151224.65]          10.0  ['Oct']                 0
# 10        11          68  [161144.96]          20.0  ['Nov']                 0
# 11        12         106  [198648.75]          30.0  ['Dec']                 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MonthNum          12 non-null     int32
#  1   CustomerID        12 non-null     int64
#  2   Total_Spend       12 non-null     object
#  3   Discount_pct      12 non-null     float64
#  4   MonthYr           12 non-null     object
#  5   Product_Launched  12 non-null     int64
# dtypes: float64(1), int32(1), int64(2), object(2)
# memory usage: 660.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MonthNum    60 non-null     int32
#  1   Location    60 non-null     object
#  2   CustomerID  60 non-null     int64
# dtypes: int32(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# Customer Acquisition (Left Y-axis)
ax1.plot(osq1d['MonthYr'], osq1d['CustomerID'],
         color='steelblue', marker='o', label='Customer Aquistion')
ax1.set_xlabel('Month')
ax1.set_ylabel('Customer Aquisition', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')

# Second Y-axis
ax2 = ax1.twinx()

# Total Spend
ax2.plot(osq1d['MonthYr'], osq1d['Total_Spend'],
         color='seagreen', marker='o', label='Total Spend')

ax2.set_ylabel('total_Spend in Million', color='black')

# Title & legend
fig.suptitle('Customer Acquisition and Total Monthly Spend')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.grid(True)
plt.show()

# %% [markdown]
# As per the analysis for customer aquisition there is not major impact of discount strategy and new product launch. New customer Aquisition is kind of impacted by marketing spend. We need more data to get into exact

# %% [markdown]
# Q3. Identify periods with the strongest and weakest retention rates. What strategies could be implemented to improve retention during weaker months?
#
# Monthly Retention rate = (Customers in Month X who returned in Month X+1) /  (total number of customers in month X)

# %%
osfinal.info()

osq3=osfinal.sort_values(('Transaction_Date'),ascending=True)

## Get count of all cusomter unique ID who did transaction in any month
osq3a=osq3.groupby('MonthNum')['CustomerID'].nunique().reset_index().sort_values('MonthNum')

## Get customer who did first transaction in any month
osq3b=osq3.drop_duplicates(subset=['CustomerID'], keep='first',ignore_index=True)
osq3b=osq3b.groupby('MonthNum')['CustomerID'].count().reset_index().sort_values('MonthNum')

# Merge the two to get new customer Id and all Customer ID for any month
osq3c= pd.merge(osq3a,osq3b,on=['MonthNum'],how='left')
osq3c = osq3c.rename(columns={'CustomerID_x':'Customer_ID_all','CustomerID_y':'Customer_ID_new'})

# Calculate retantion percentage
osq3c['Customer_ID_Ret'] = osq3c['Customer_ID_all'] - osq3c['Customer_ID_new']
#print(osq3c)
osq3c['Customer_Ret_Per'] = osq3c.Customer_ID_Ret.shift(-1) / osq3c.Customer_ID_all * 100
#print(osq3c)
osq3c['Customer_Ret_Per'] = osq3c['Customer_Ret_Per'].shift(+1)
osq3c['Customer_Ret_Per'] = osq3c['Customer_Ret_Per'].round(2)

osq3d= pd.merge(osq3c,osq1d[['MonthNum','Total_Spend']],on=['MonthNum'],how='left')

# Mark Null for very first month to Zero
osq3d=osq3d.fillna(0)
print(osq3d)
osq3d = osq3d.sort_values('Customer_Ret_Per').reset_index(drop=True)
print(osq3d)
osq3d

#### Create Retention percentage plot for every month and understand month with lower values

plt.figure(figsize=(20, 8))
plt.subplot(2, 2, 1)
plt.plot(osq3d['MonthNum'], osq3d['Customer_Ret_Per'],marker='o',color='steelblue', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Customer Retention percentage')
plt.title('Monthly customer Retention Trend')

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  MonthYr              52924 non-null  object
#  11  MonthNum             52924 non-null  int32
#  12  Discount_pct         52924 non-null  float64
#  13  GST                  52924 non-null  float64
#  14  Rev                  52924 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(3), object(5)
# memory usage: 5.9+ MB
#     MonthNum  Customer_ID_all  Customer_ID_new  Customer_ID_Ret  \
# 0          1              215              215                0
# 1          2              109               96               13
# 2          3              208              177               31
# 3          4              224              163               61
# 4          5              200              112               88
# 5          6              259              137              122
# 6          7              236               94              142
# 7          8              300              135              165
# 8          9              193               78              115
# 9         10              210               87              123
# 10        11              188               68              120
# 11        12              236              106              130
#
#     Customer_Ret_Per  Total_Spend
# 0               0.00  [154928.95]
# 1               6.05  [137107.92]
# 2              28.44  [122250.09]
# 3              29.33  [157026.83]
# 4              39.29  [118259.64]
# 5              61.00  [134318.14]
# 6              54.83  [120217.85]
# 7              69.92  [142904.15]
# 8              38.33  [135514.54]
# 9              63.73  [151224.65]
# 10             57.14  [161144.96]
# 11             69.15  [198648.75]
#     MonthNum  Customer_ID_all  Customer_ID_new  Customer_ID_Ret  \
# 0          1              215              215                0
# 1          2              109               96               13
# 2          3              208              177               31
# 3          4              224              163               61
# 4          9              193               78              115
# 5          5              200              112               88
# 6          7              236               94              142
# 7         11              188               68              120
# 8          6              259              137              122
# 9         10              210               87              123
# 10        12              236              106              130
# 11         8              300              135              165
#
#     Customer_Ret_Per  Total_Spend
# 0               0.00  [154928.95]
# 1               6.05  [137107.92]
# 2              28.44  [122250.09]
# 3              29.33  [157026.83]
# 4              38.33  [135514.54]
# 5              39.29  [118259.64]
# 6              54.83  [120217.85]
# 7              57.14  [161144.96]
# 8              61.00  [134318.14]
# 9              63.73  [151224.65]
# 10             69.15  [198648.75]
# 11             69.92  [142904.15]

# %%
osq3e=osq3d.sort_values('MonthNum')
print(osq3e)

fig, ax1 = plt.subplots(figsize=(10, 5))

# Customer Acquisition (Left Y-axis)
ax1.plot(osq3e['MonthNum'], osq3e['Customer_Ret_Per'],
         color='steelblue', marker='o', label='Customer Retention Percentage')
ax1.set_xlabel('Month')
ax1.set_ylabel('Customer Aquisition', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')

# Second Y-axis
ax2 = ax1.twinx()

# Total Spend
ax2.plot(osq3e['MonthNum'], osq3e['Total_Spend'],
         color='seagreen', marker='o', label='Total Spend')

ax2.set_ylabel('total_Spend in Million', color='black')

# Title & legend
fig.suptitle('TRend for Customer Retention and Total Monthly Spend')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])

plt.grid(True)
plt.show()
# Out:
#     MonthNum  Customer_ID_all  Customer_ID_new  Customer_ID_Ret  \
# 0          1              215              215                0
# 1          2              109               96               13
# 2          3              208              177               31
# 3          4              224              163               61
# 5          5              200              112               88
# 8          6              259              137              122
# 6          7              236               94              142
# 11         8              300              135              165
# 4          9              193               78              115
# 9         10              210               87              123
# 7         11              188               68              120
# 10        12              236              106              130
#
#     Customer_Ret_Per  Total_Spend
# 0               0.00  [154928.95]
# 1               6.05  [137107.92]
# 2              28.44  [122250.09]
# 3              29.33  [157026.83]
# 5              39.29  [118259.64]
# 8              61.00  [134318.14]
# 6              54.83  [120217.85]
# 11             69.92  [142904.15]
# 4              38.33  [135514.54]
# 9              63.73  [151224.65]
# 7              57.14  [161144.96]
# 10             69.15  [198648.75]

# %% [markdown]
# Analyze customer behavior during high-retention months and suggest ways to replicate this success throughout the year.

# %%
#print(osq3)
#osq1c=osq3.drop_duplicates(subset=['Product_Category'], keep='first',ignore_index=True)
#osq1.info()
osq4a=osq3.groupby(['Product_Category','MonthNum'])['Quantity'].sum().reset_index().sort_values('Product_Category')
#print(osq4a)

osq4b=osq4a[osq4a['Product_Category'].isin(['Office', 'Apparel', 'Drinkware','Nest-USA'])]

osq4b=osq4b.sort_values(['Product_Category','MonthNum'], ascending=True)
print(osq4b)

osq4a=osq4a[osq4a['MonthNum'].isin([10, 12, 8])]
osq4a=osq4a.sort_values('Quantity', ascending=False)
print(osq4a)
plt.figure(figsize=(20, 8))

sns.boxplot(
    data=osq4a,
    x='MonthNum',
    y='Quantity',
    hue='Product_Category',
    palette='Set2'
)

plt.xlabel('Month')
plt.ylabel('Quantity')
plt.title('Monthly Quantity Distribution by Product Category')
plt.legend(title='Product Category')
plt.tight_layout()
plt.show()
# Out:
#     Product_Category  MonthNum  Quantity
# 19           Apparel         1      1500
# 20           Apparel         2      1559
# 21           Apparel         3      2303
# 22           Apparel         4      4052
# 23           Apparel         5      2829
# 24           Apparel         6      2551
# 25           Apparel         7      4307
# 26           Apparel         8      3950
# 27           Apparel         9      3731
# 28           Apparel        10      1733
# 29           Apparel        11      1247
# 30           Apparel        12      2676
# 64         Drinkware         1      2140
# 65         Drinkware         2      1866
# 66         Drinkware         3      2976
# 67         Drinkware         4      3022
# 68         Drinkware         5      2272
# 69         Drinkware         6      3353
# 70         Drinkware         7      2539
# 71         Drinkware         8      3900
# 72         Drinkware         9      3169
# 73         Drinkware        10      2997
# 74         Drinkware        11      1649
# 75         Drinkware        12       618
# 160         Nest-USA         1      2261
# 161         Nest-USA         2      1638
# 162         Nest-USA         3      1680
# 163         Nest-USA         4      1557
# 164         Nest-USA         5      1496
# 165         Nest-USA         6      1627
# 166         Nest-USA         7      1759
# 167         Nest-USA         8      1684
# 168         Nest-USA         9      1434
# 169         Nest-USA        10      1739
# 170         Nest-USA        11      2266
# 171         Nest-USA        12      2289
# 183           Office         1     10237
# 184           Office         2      6389
# 185           Office         3      8940
# 186           Office         4      9106
# 187           Office         5      7441
# 188           Office         6      9294
# 189           Office         7      5993
# 190           Office         8      8076
# 191           Office         9      5514
# 192           Office        10      5507
# 193           Office        11      7028
# 194           Office        12      4858
#          Product_Category  MonthNum  Quantity
# 190                Office         8      8076
# 192                Office        10      5507
# 194                Office        12      4858
# 26                Apparel         8      3950
# 71              Drinkware         8      3900
# 73              Drinkware        10      2997
# 135             Lifestyle        10      2680
# 179  Notebooks & Journals         8      2677
# 30                Apparel        12      2676
# 133             Lifestyle         8      2366
# 171              Nest-USA        12      2289
# 49                   Bags         8      2110
# 169              Nest-USA        10      1739
# 28                Apparel        10      1733
# 167              Nest-USA         8      1684
# 112              Headgear         8      1683
# 51                   Bags        10      1534
# 147                  Nest        12       944
# 75              Drinkware        12       618
# 124            Housewares         8       583
# 145                  Nest        10       576
# 137             Lifestyle        12       566
# 53                   Bags        12       238
# 8             Accessories        10       201
# 10            Accessories        12       200
# 63                Bottles        10       175
# 206                  Waze        12       104
# 143                  Nest         8       104
# 61                Bottles         8        93
# 204                  Waze        10        90
# 202                  Waze         8        88
# 116              Headgear        12        74
# 95             Gift Cards        10        68
# 114              Headgear        10        63
# 182  Notebooks & Journals        12        55
# 83                    Fun         8        48
# 159           Nest-Canada        12        34
# 157           Nest-Canada        10        34
# 155           Nest-Canada         8        30
# 40              Backpacks        10        19
# 38              Backpacks         8        15
# 104                Google         8        15
# 93             Gift Cards         8        14
# 6             Accessories         8        14
# 96             Gift Cards        12        11
# 18                Android         8         7
# 85                    Fun        10         6
# 181  Notebooks & Journals        10         3

# %% [markdown]
#  Compare the revenue generated by new and existing customers month-over-month. What does this trend suggest about the balance between acquisition and retention efforts?

# %%
# osfinal is DF which will be used in all questions as it has all data require to work
#osfinal.info()

# Sorting value on transaction date to keep only first tranasction to get count of new customer/month
# Dropping duplicate
osq5=osfinal.sort_values(('Transaction_Date'),ascending=True)
osq5a=osq5.drop_duplicates(subset=['CustomerID'], keep='first',ignore_index=True)

## Extracting all records from OS where customer onboarded on that month
osq5a=pd.merge(osfinal,osq5a[['CustomerID','MonthYr']],on=(['CustomerID','MonthYr']), how='inner')
#osq5a.info()

# Belwo command is to test that data coming is correct for new customer in a month
#osq5t=osq5a.groupby('MonthNum')['CustomerID'].nunique().reset_index().sort_values('MonthNum')
#print(osq5t)

osq5b=osq5a.groupby('MonthNum').agg({'CustomerID':'count','Rev':'sum'}).reset_index().sort_values('MonthNum')
osq5b = osq5b.rename(columns=({'Rev':'Rev_New_Customer','CustomerID':'Customer_new_Count'}))
print(osq5b)

# Below command is to get only those record who are found in osfinal but not in osq5a
osq5c=pd.merge(osfinal,osq5a[['CustomerID','MonthYr']],on=(['CustomerID','MonthYr']), how='left',indicator='True')
osq5c=osq5c[osq5c['True'] == 'left_only'].drop(['True'],axis=1)

# Creating groupby for existing customer revenue
osq5c=osq5c.groupby('MonthNum').agg({'CustomerID':'count','Rev':'sum'}).reset_index().sort_values('MonthNum')
osq5c = osq5c.rename(columns=({'Rev':'Rev_exi_Customer','CustomerID':'Customer_exi_Count'}))
print(osq5c)

osq5f=pd.merge(osq5b,osq5c,on=['MonthNum'],how='left')
#osq5f = osq5f.rename(columns=({'CustomerID':'CustomerCount'}))
osq5f=osq5f.fillna(0)
osq5f['Total_rev'] = osq5f['Rev_New_Customer'] + osq5f['Rev_exi_Customer']
osq5f['Total_rev'] = osq5f['Total_rev'].round(2)
osq5f['Rev_New_Customer_per'] = (osq5f['Rev_New_Customer'] / osq5f['Total_rev']) * 100
osq5f['Rev_exi_Customer_per'] = (osq5f['Rev_exi_Customer'] / osq5f['Total_rev']) * 100
osq5f['Rev_New_Customer_per'] = osq5f['Rev_New_Customer_per'].round(2)
osq5f['Rev_exi_Customer_per'] = osq5f['Rev_exi_Customer_per'].round(2)
print(osq5f)
# Out:
#     MonthNum  Customer_new_Count  Rev_New_Customer
# 0          1                4063         470487.12
# 1          2                2847         296768.06
# 2          3                3583         295932.47
# 3          4                2850         268307.32
# 4          5                3020         210455.88
# 5          6                2461         185053.98
# 6          7                2101         171518.11
# 7          8                3155         206528.41
# 8          9                1842         139258.22
# 9         10                2143         245149.46
# 10        11                1787         211523.17
# 11        12                2181         220997.00
#     MonthNum  Customer_exi_Count  Rev_exi_Customer
# 0          2                 437          42285.96
# 1          3                 763          60328.19
# 2          4                1300         186249.63
# 3          5                1552         118517.67
# 4          6                1732         123870.28
# 5          7                3150         259154.95
# 6          8                2995         225439.70
# 7          9                2446         200104.91
# 8         10                2021         212347.49
# 9         11                2174         281027.18
# 10        12                2321         246531.24
#     MonthNum  Customer_new_Count  Rev_New_Customer  Customer_exi_Count  \
# 0          1                4063         470487.12                 0.0
# 1          2                2847         296768.06               437.0
# 2          3                3583         295932.47               763.0
# 3          4                2850         268307.32              1300.0
# 4          5                3020         210455.88              1552.0
# 5          6                2461         185053.98              1732.0
# 6          7                2101         171518.11              3150.0
# 7          8                3155         206528.41              2995.0
# 8          9                1842         139258.22              2446.0
# 9         10                2143         245149.46              2021.0
# 10        11                1787         211523.17              2174.0
# 11        12                2181         220997.00              2321.0
#
#     Rev_exi_Customer  Total_rev  Rev_New_Customer_per  Rev_exi_Customer_per
# 0               0.00  470487.12                100.00                  0.00
# 1           42285.96  339054.02                 87.53                 12.47
# 2           60328.19  356260.66                 83.07                 16.93
# 3          186249.63  454556.95                 59.03                 40.97
# 4          118517.67  328973.55                 63.97                 36.03
# 5          123870.28  308924.26                 59.90                 40.10
# 6          259154.95  430673.06                 39.83                 60.17
# 7          225439.70  431968.11                 47.81                 52.19
# 8          200104.91  339363.13                 41.04                 58.96
# 9          212347.49  457496.95                 53.58                 46.42
# 10         281027.18  492550.35                 42.94                 57.06
# 11         246531.24  467528.24                 47.27                 52.73

# %%
fig, ax1 = plt.subplots(figsize=(10, 5))

# Customer Acquisition (Left Y-axis)
ax1.plot(osq5f['MonthNum'], osq5f['Rev_New_Customer_per'],
         color='steelblue', marker='o', label='Revenue New Customer')
ax1.set_xlabel('Month')
ax1.set_ylabel('New Customer Rev', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')

# Second Y-axis
ax2 = ax1.twinx()

# Total Spend
ax2.plot(osq5f['MonthNum'], osq5f['Rev_exi_Customer_per'],
         color='seagreen', marker='o', label='Revenue existing Customer')

ax2.set_ylabel('Existing Customer Rev', color='black')

# Title & legend
fig.suptitle('New vs Existing customer Rev trend')

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])

y_min = min(osq5f['Rev_exi_Customer_per'].min(), osq5f['Rev_New_Customer_per'].min())
y_max = max(osq5f['Rev_exi_Customer_per'].max(), osq5f['Rev_New_Customer_per'].max())

ax1.set_ylim(y_min, y_max)
ax2.set_ylim(y_min, y_max)


lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')


plt.grid(True)
plt.show()

# %% [markdown]
# Analyze the relationship between coupon usage and revenue generation. How can discount strategies be optimized to maximize revenue while maintaining profitability?

# %%
print(osfinal.head(1))

# First extraction data where no coupan is available
osq7a = osfinal[osfinal['Discount_pct'] == 0.0]
#print(osq7a)

# Extracting data where discount is available on product category
osq7b = osfinal[osfinal['Discount_pct'] != 0.0]
#print(osq7b)
#osq7b.to_csv(r'/content/sample_data/CaseStudy/prod_cat_rev.csv')


# Extracting data where coupan is used and this will be final data to evaluate coupan trend
osq7b1=osq7b[osq7b['Coupon_Status'] != 'Not Used']
osq7d=osq7b1.groupby(['Product_Category','MonthNum']).agg({'Rev':'sum','Quantity':'sum'}).reset_index().sort_values('Rev',ascending=False)
#print(osq7d)
#print('#############')

# Get top Product description by Revenue for each product category
osq7f=osq7b1.groupby(['Product_Description','Product_Category']).agg({'Rev':'sum','Quantity':'sum'}).reset_index().sort_values('Rev',ascending=False)
#print(osq7f)
#print(osq7f.head(10))
#print(osq7f.tail(10))



# Grouping month on month trend for Product category where coupan is not provided
#osq7c=osq7a.groupby('MonthNum').agg({'Rev':'sum'}).reset_index().sort_values('Rev',ascending=False)
#osq7c=osq7a.groupby(['Product_Category','MonthNum']).agg({'Rev':'sum','Quantity':'sum'}).reset_index().sort_values('Rev',ascending=False)
#print(osq7c)

# Grouping month on month for Product category where coupan is provided as well as used or clicked
#osq7d=osq7b1.groupby('MonthNum').agg({'Rev':'sum'}).reset_index().sort_values('Rev',ascending=False)
#print(osq7d)

# Grouping month on month for Product category where coupan is provided, irrespective of status
#osq7e=osq7b.groupby('MonthNum').agg({'Rev':'sum'}).reset_index().sort_values('Rev',ascending=False)
#print(osq7e)

#Getting Revenue and quantity where coupan is used and it's significance

#group all paroduct cateogory on product description
osq7e=osfinal.drop_duplicates(subset=['Product_Description'], keep='first',ignore_index=True)
osprde=osq7e[['Product_Description','Product_Category','MonthNum','Discount_pct']].sort_values('Product_Category')
#print(osprde)

#osprde.info()

## plot discount on various category on monthly basis. There is no category based discount

plt.figure(figsize=(15, 8))
#plt.subplot(1, 3, 1)
sns.lineplot(
    data=osprde,
    x='MonthNum',
    y='Discount_pct',
    marker='o'
    #hue='Product_Category'
)

plt.xlabel('Month')
plt.ylabel('Discount percentage')
#plt.title('Monthly Discount % Trend by Product Category')

plt.legend(
    title='Monthly Discount % Trend by Product Category',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)
plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show()

# Plot category wise monthly revenue. This will provide detail
plt.figure(figsize=(15, 8))
sns.lineplot(
    data=osq7d,
    x='MonthNum',
    y='Rev',
    hue='Product_Category'
)

plt.xlabel('Month')
plt.ylabel('Revenue')
plt.title('Monthly Rev by Product Category')

plt.legend(
    title='Monthly Rev by Product Category',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show()

'''
sns.boxplot(
    data=osq1d,
    x='MonthNum',
    y='Discount_pct'
)

plt.xlabel('Product Category')
plt.ylabel('Quantity')
plt.title('Discount per month')
plt.show()
'''
'''
plt.hist(osq1d['MonthNum'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('Month')
plt.ylabel('Discount_pct')
plt.title('Distribution of Quantity')
plt.show()
'''
'''
plt.scatter(osq1d['MonthYr_str'], osq1d['Discount_pct'], color='darkorange')
plt.title('Monthly Discount vs Monthly Customer Acquisition')
plt.xlabel('Discount %')
plt.ylabel('Customer Acquisition')
plt.scatter(osq7f['Discount_pct'], osq1d['CustomerID'], color='darkorange')
plt.title('Monthly Discount vs Monthly Customer Acquisition')
plt.xlabel('Discount %')
plt.ylabel('Customer Acquisition')'''
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status MonthYr  MonthNum  \
# 0         1     153.71               6.5          Used     Jan         1
#
#    Discount_pct  GST     Rev
# 0          10.0  0.1  158.67
# /tmp/ipython-input-3010684210.py:65: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(
# "\nplt.scatter(osq1d['MonthYr_str'], osq1d['Discount_pct'], color='darkorange')\nplt.title('Monthly Discount vs Monthly Customer Acquisition')\nplt.xlabel('Discount %')\nplt.ylabel('Customer Acquisition')\nplt.scatter(osq7f['Discount_pct'], osq1d['CustomerID'], color='darkorange')\nplt.title('Monthly Discount vs Monthly Customer Acquisition')\nplt.xlabel('Discount %')\nplt.ylabel('Customer Acquisition')"

# %% [markdown]
# Discount are same across all categories and chaning only on monthly basis. there are categories such as NEST_USA, NEST, Apparel, office which gives us lot of revenue and having good volume as well. We should have flexible discount approach rather than having fixed discount accross all categories.

# %% [markdown]
# 8. Analyze the relationship between monthly marketing spend and revenue. Are there any months where marketing efforts yielded disproportionately high or low returns? How can marketing strategies be adjusted to improve ROI?

# %%
ms['Total_Spend'] = ms['Offline_Spend'] + ms['Online_Spend']

#mstest=ms[ms['MonthNum'] == 9]
#print(mstest)

#mstest=ms[ms['MonthNum'] == 7]
#print(mstest)

ms2=ms.groupby(['MonthNum','MonthYr']).agg({'Total_Spend':'sum'}).reset_index()


osq8=osfinal.groupby(['MonthNum','MonthYr']).agg({'Rev':'sum'}).reset_index()


osq8a=pd.merge(osq8,ms2,on=['MonthNum','MonthYr'],how='left')


osq8a['ROI'] = (osq8a['Rev'] - osq8a['Total_Spend']) / osq8a['Total_Spend'] * 100

osq8a['ROI'] = osq8a['ROI'].round(2)

print(osq8a)
## Plotting ROI on monthly basis

# Plot category wise monthly revenue. This will provide detail
plt.figure(figsize=(15, 8))
sns.lineplot(
    data=osq8a,
    x='MonthNum',
    y='ROI',
    marker='o',
    color='orange'
)

plt.xlabel('Month')
plt.ylabel('ROI')
plt.title('Monthly ROI against total marketing spend')

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show()


''' There is no trend coming from this code so not using this graphs

ms1=ms.groupby('MonthNum')['Offline_Spend'].sum().reset_index()
print(ms1)
osq8onl=pd.merge(osfinal,ms1,on=['MonthNum'],how='left')
#print(osnewof2)

ms3=ms.groupby('MonthNum')['Online_Spend'].sum().reset_index()
#print(ms2)
print(ms3)
osq8ofl=pd.merge(osfinal,ms3,on=['MonthNum'],how='left')
#print(osnewo1)


#### Getting monthly online plotting

plt.figure(figsize=(15, 8))
sns.lineplot(
    data=ms3,
    x='MonthNum',
    y='Online_Spend',
    marker='o'
)

plt.xlabel('Month')
plt.ylabel('Online_Spend')
plt.title('Monthly Online_Spend trend')

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show()

#### Monthly offline spend trend

plt.figure(figsize=(15, 8))
sns.lineplot(
    data=ms1,
    x='MonthNum',
    y='Offline_Spend',
    marker='o'
)

plt.xlabel('Month')
plt.ylabel('Offline_Spend')
plt.title('Monthly Offline Spend trend')

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show() '''
# Out:
#     MonthNum MonthYr        Rev  Total_Spend     ROI
# 0          1     Jan  470487.12    154928.95  203.68
# 1          2     Feb  339054.02    137107.92  147.29
# 2          3     Mar  356260.66    122250.09  191.42
# 3          4     Apr  454556.95    157026.83  189.48
# 4          5     May  328973.55    118259.64  178.18
# 5          6     Jun  308924.26    134318.14  129.99
# 6          7     Jul  430673.06    120217.85  258.24
# 7          8     Aug  431968.11    142904.15  202.28
# 8          9     Sep  339363.13    135514.54  150.43
# 9         10     Oct  457496.95    151224.65  202.53
# 10        11     Nov  492550.35    161144.96  205.66
# 11        12     Dec  467528.24    198648.75  135.35
# /tmp/ipython-input-4219090431.py:39: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(
# " There is no trend coming from this code so not using this graphs\n\nms1=ms.groupby('MonthNum')['Offline_Spend'].sum().reset_index()\nprint(ms1)\nosq8onl=pd.merge(osfinal,ms1,on=['MonthNum'],how='left')\n#print(osnewof2)\n\nms3=ms.groupby('MonthNum')['Online_Spend'].sum().reset_index()\n#print(ms2)\nprint(ms3)\nosq8ofl=pd.merge(osfinal,ms3,on=['MonthNum'],how='left')\n#print(osnewo1)\n\n\n#### Getting monthly online plotting\n\nplt.figure(figsize=(15, 8))\nsns.lineplot(\n    data=ms3,\n    x='MonthNum',\n    y='Online_Spend',\n    marker='o'\n)\n\nplt.xlabel('Month')\nplt.ylabel('Online_Spend')\nplt.title('Monthly Online_Spend trend')\n\nplt.legend(\n    bbox_to_anchor=(1.05, 1),\n    loc='upper left'\n)\n\nplt.xticks(ticks=range(1, 13), labels=[\n    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'\n])\nplt.tight_layout()\nplt.show()\n\n#### Monthly offline spend trend\n\nplt.figure(figsize=(15, 8))\nsns.lineplot(\n    data=ms1,\n    x='MonthNum',\n    y='Offline_Spend',\n    marker='o'\n)\n\nplt.xlabel('Month')\nplt.ylabel('Offline_Spend')\nplt.title('Monthly Offline Spend trend')\n\nplt.legend(\n    bbox_to_anchor=(1.05, 1),\n    loc='upper left'\n)\n\nplt.xticks(ticks=range(1, 13), labels=[\n    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'\n])\nplt.tight_layout()\nplt.show() "

# %% [markdown]
# There is ROI decrease in Month of June, Aug, Sep and Dec. Out of these 4 months for 3 months Marketing spend has increased from previous month, having said that there is no direct rleation against ROI. One observation, we have in month of Dec we have done marketing spend increase of 20+% to around 200K, as per data we should keep marketing spend / month in the range of 120-150K (+- 5%) based on new product launch or festive seasons, if any

# %% [markdown]
# 9. Evaluate the effectiveness of marketing campaigns by comparing marketing spend to revenue generated. Are there opportunities to reallocate resources for better results?

# %%
print(osq8a)
osq9a=osq8a
osq9a['spend_per'] = (osq9a['Total_Spend'] / osq9a['Rev']) * 100
osq9a['spend_per'] = osq9a['spend_per'].round(2)
osq9a=osq9a.sort_values('Total_Spend',ascending=False)
print(osq9a)

plt.figure(figsize=(15, 8))
sns.lineplot(
    data=osq8a,
    x='MonthNum',
    y='spend_per',
    marker='o',
    color='orange'
)

plt.xlabel('Month')
plt.ylabel('spend_per')
plt.title('Marketing Spend percemtage against total Rev')

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.xticks(ticks=range(1, 13), labels=[
    'Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'
])
plt.tight_layout()
plt.show()
# Out:
#     MonthNum MonthYr        Rev  Total_Spend     ROI  spend_per
# 0          1     Jan  470487.12    154928.95  203.68      32.93
# 1          2     Feb  339054.02    137107.92  147.29      40.44
# 2          3     Mar  356260.66    122250.09  191.42      34.31
# 3          4     Apr  454556.95    157026.83  189.48      34.55
# 4          5     May  328973.55    118259.64  178.18      35.95
# 5          6     Jun  308924.26    134318.14  129.99      43.48
# 6          7     Jul  430673.06    120217.85  258.24      27.91
# 7          8     Aug  431968.11    142904.15  202.28      33.08
# 8          9     Sep  339363.13    135514.54  150.43      39.93
# 9         10     Oct  457496.95    151224.65  202.53      33.05
# 10        11     Nov  492550.35    161144.96  205.66      32.72
# 11        12     Dec  467528.24    198648.75  135.35      42.49
#     MonthNum MonthYr        Rev  Total_Spend     ROI  spend_per
# 11        12     Dec  467528.24    198648.75  135.35      42.49
# 10        11     Nov  492550.35    161144.96  205.66      32.72
# 3          4     Apr  454556.95    157026.83  189.48      34.55
# 0          1     Jan  470487.12    154928.95  203.68      32.93
# 9         10     Oct  457496.95    151224.65  202.53      33.05
# 7          8     Aug  431968.11    142904.15  202.28      33.08
# 1          2     Feb  339054.02    137107.92  147.29      40.44
# 8          9     Sep  339363.13    135514.54  150.43      39.93
# 5          6     Jun  308924.26    134318.14  129.99      43.48
# 2          3     Mar  356260.66    122250.09  191.42      34.31
# 6          7     Jul  430673.06    120217.85  258.24      27.91
# 4          5     May  328973.55    118259.64  178.18      35.95
# /tmp/ipython-input-3432448558.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(

# %% [markdown]
# There is spend percetage increase in Month of June, Aug, Sep and Dec. Out of these 4 months for 3 months Marketing spend has increased from previous month, havign said that there is no direct relation against Rev increase/decrease. One observation, we have in month of Dec we have done marketing spend increase of 20+% to around 200K, as per data we should keep marketing spend / month in the range of 120-150K (+- 5%) based on new product launch or festive seasons, if any

# %% [markdown]
# 10. Segment customers into groups such as Premium, Gold, Silver, and Standard. What targeted strategies can be developed for each segment to improve retention and revenue? (Use RFM segmentation techniques)10. Segment customers into groups such as Premium, Gold, Silver, and Standard. What targeted strategies can be developed for each segment to improve retention and revenue? (Use RFM segmentation techniques)

# %%
osfinal.info()
Today = pd.to_datetime('2020-01-01')
print(Today)

osq10a=osfinal.groupby('CustomerID').agg({'Quantity':'sum','Rev':'sum','Transaction_Date':
                                          lambda x:(Today - x.max()).days}).reset_index().sort_values('Quantity',ascending=False)

osq10a=osq10a.rename(columns={'Quantity':'Frequency','Rev':'Monetary','Transaction_Date':'Recency'})

print(osq10a)

plt.figure(figsize=(15, 4))

# Frequency
plt.subplot(1, 3, 1)
plt.hist(osq10a['Frequency'], bins=10, color='skyblue', edgecolor='black')
plt.title('Frequency Distribution')
plt.xlabel('Frequency')
plt.ylabel('Count')

# Monetary
plt.subplot(1, 3, 2)
plt.hist(osq10a['Monetary'], bins=10, color='lightgreen', edgecolor='black')
plt.title('Monetary Distribution')
plt.xlabel('Monetary Value')

# Recency
plt.subplot(1, 3, 3)
plt.hist(osq10a['Recency'], bins=10, color='salmon', edgecolor='black')
plt.title('Recency Distribution')
plt.xlabel('Recency (days)')

plt.tight_layout()
plt.show()

# Defining bins

f_bins = [0, 1250, 2500, 3750, np.inf]
r_bins = [0, 75, 150, 225, np.inf]
m_bins = [0, 20000, 40000, 600000, np.inf]

osq10a['R_Score'] = pd.cut(osq10a['Recency'], bins=r_bins, labels=False) + 1
osq10a['F_Score'] = pd.cut(osq10a['Frequency'], bins=f_bins, labels=False) + 1
osq10a['M_Score'] = pd.cut(osq10a['Monetary'], bins=m_bins, labels=False) + 1

print(osq10a.info())
osq10a['final_RFM'] = osq10a['R_Score'] + osq10a['F_Score'] + osq10a['M_Score']

print(osq10a)

# RFM
plt.figure(figsize=(15, 4))
#plt.subplot(1, 3, 3)
plt.hist(osq10a['final_RFM'], bins=10, color='blue', edgecolor='black')
plt.title('RFM Distribution')
plt.xlabel('RFM')

plt.tight_layout()
plt.show()

conditions = [
    osq10a['final_RFM'] <= 4,
    osq10a['final_RFM'] <= 7,
    osq10a['final_RFM'] <= 9
]

choices = [
    'Low Value',
    'Mid Value',
    'High Value'
]

osq10a['RFMLevel'] = np.select(conditions, choices, default='Top Value')

# RFM
plt.figure(figsize=(15, 4))
#plt.subplot(1, 3, 3)
plt.hist(osq10a['RFMLevel'], bins=10, color='blue', edgecolor='black')
plt.title('RFM Distribution')
plt.xlabel('RFM')

plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  MonthYr              52924 non-null  object
#  11  MonthNum             52924 non-null  int32
#  12  Discount_pct         52924 non-null  float64
#  13  GST                  52924 non-null  float64
#  14  Rev                  52924 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(3), object(5)
# memory usage: 5.9+ MB
# 2020-01-01 00:00:00
#       CustomerID  Frequency  Monetary  Recency
# 118        12748       4869  80700.68      108
# 736        15311       4211  78710.83       13
# 563        14606       3127  60322.08        1
# 1355       17841       2626  51231.57       18
# 214        13113       2494  21124.82        8
# ...          ...        ...       ...      ...
# 1085       16810          1     35.59      223
# 1005       16500          1     15.06      128
# 1031       16593          1      7.72      118
# 1014       16532          1     17.15      164
# 993        16424          1     18.54      157
#
# [1468 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 1468 entries, 118 to 993
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  1468 non-null   int64
#  1   Frequency   1468 non-null   int64
#  2   Monetary    1468 non-null   float64
#  3   Recency     1468 non-null   int64
#  4   R_Score     1468 non-null   int64
#  5   F_Score     1468 non-null   int64
#  6   M_Score     1468 non-null   int64
# dtypes: float64(1), int64(6)
# memory usage: 91.8 KB
# None
#       CustomerID  Frequency  Monetary  Recency  R_Score  F_Score  M_Score  \
# 118        12748       4869  80700.68      108        2        4        3
# 736        15311       4211  78710.83       13        1        4        3
# 563        14606       3127  60322.08        1        1        3        3
# 1355       17841       2626  51231.57       18        1        3        3
# 214        13113       2494  21124.82        8        1        2        2
# ...          ...        ...       ...      ...      ...      ...      ...
# 1085       16810          1     35.59      223        3        1        1
# 1005       16500          1     15.06      128        2        1        1
# 1031       16593          1      7.72      118        2        1        1
# 1014       16532          1     17.15      164        3        1        1
# 993        16424          1     18.54      157        3        1        1
#
#       final_RFM
# 118           9
# 736           8
# 563           7
# 1355          7
# 214           5
# ...         ...
# 1085          5
# 1005          4
# 1031          4
# 1014          5
# 993           5
#
# [1468 rows x 8 columns]
